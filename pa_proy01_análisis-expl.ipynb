# %%
import pandas as pd 
% matplotlib inline

#df =pd.read_excel('C:/Users/bran/Desktop/Hist/saat2017.xlsx','Hoja1')
#train=df[0:8761]
#test=df[8761:]
#train.head(3)
#train.tail(3)
#test.head(3)
#test.tail(3)

#train.to_csv('train.csv', encoding='utf-8')
#test.to_csv('test.csv', encoding='utf-8')

import numpy as np
import matplotlib.pyplot as plt 

train = pd.read_csv('C:/Users/bran/Desktop/Hist/arima/train.csv')
test = pd.read_csv('C:/Users/bran/Desktop/Hist/arima/test.csv')
train.head()
test.head()
# Out:
#    Unnamed: 0                   ds  y
# 0        8762  2018-01-01 02:00:00  1
# 1        8763  2018-01-01 03:00:00  0
# 2        8764  2018-01-01 04:00:00  2
# 3        8765  2018-01-01 05:00:00  2
# 4        8766  2018-01-01 06:00:00  1

# %%
train.ds = pd.to_datetime(train.ds)
train.index = train.ds 
train.y.plot(figsize=(15,8), title= 'Cantidad', fontsize=14)

# %%
test.ds = pd.to_datetime(test.ds)
test.index = test.ds 
test.y.plot(figsize=(15,8), title= 'Cantidad', fontsize=14)

# %%
#train = train.resample('D').mean() 
#test = test.resample('D').mean() 
train.y.plot(figsize=(15,8), title= 'cant', fontsize=14)
test.y.plot(figsize=(15,8), title= 'cant', fontsize=14)
